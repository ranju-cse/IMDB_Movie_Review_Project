# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('IMDB Dataset.csv')

# %%
df
# Out:
#                                                   Review Sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Text Preprocessing

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.describe()
# Out:
#                                                    Review Sentiment
# count                                               50000     50000
# unique                                              49582         2
# top     Loved today's show!!! It was a variety and not...  positive
# freq                                                    5     25000

# %%
#check null values
df.isnull().sum()
# Out:
# Review       0
# Sentiment    0
# dtype: int64

# %%
df
# Out:
#                                                   Review Sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Removing HTML Tags

# %%
# 1. Remove all HTML tags (the non-greedy way)
df['Review'] = df['Review'].str.replace(r"<.*?>", " ", regex=True)

# %%
df
# Out:
#                                                   Review Sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production.   The filming t...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # Removing Quotes

# %%
# This removes: , (comma), ' (single quote), and " (double quote)
df['Review'] = df['Review'].str.replace(r"[ ().'\" ]", " ", regex=True)

# %% [markdown]
# # Lowercasing

# %%
df['Review']=df['Review'].str.lower()

# %%
df['Review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production    the filming t...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there s a family where a little boy ...
# 4        petter mattei s  love in the time of money  is...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot, bad dialogue, bad acting, idiotic di...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i m going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: Review, Length: 50000, dtype: object

# %% [markdown]
# # Remove Punctuation

# %%
df['Review'] = df['Review'].str.replace(r"[^a-zA-Z0-9]"," ",regex=True)
df["Review"] = df["Review"].str.replace(r"\s+"," ",regex=True).str.strip()

# %%
df['Review']
# Out:
# 0        one of the other reviewers has mentioned that ...
# 1        a wonderful little production the filming tech...
# 2        i thought this was a wonderful way to spend ti...
# 3        basically there s a family where a little boy ...
# 4        petter mattei s love in the time of money is a...
#                                ...
# 49995    i thought this movie did a down right good job...
# 49996    bad plot bad dialogue bad acting idiotic direc...
# 49997    i am a catholic taught in parochial elementary...
# 49998    i m going to have to disagree with the previou...
# 49999    no one expects the star trek movies to be high...
# Name: Review, Length: 50000, dtype: object

# %% [markdown]
# # Tokenization

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
def tokenize_clean(text):
    tokens=word_tokenize(text)
    return tokens
df['Review'] = df['Review'].apply(tokenize_clean)

# %% [markdown]
# # Remove Stop Words

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
# Keep negation words
negation_words = {'not', 'no', 'nor', 'never'}
stop_words = stop_words - negation_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hpwor\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    return " ".join(
        [word for word in text.split() if word.lower() not in stop_words]
    )

# %%
df["Review"]
# Out:
# 0        [one, of, the, other, reviewers, has, mentione...
# 1        [a, wonderful, little, production, the, filmin...
# 2        [i, thought, this, was, a, wonderful, way, to,...
# 3        [basically, there, s, a, family, where, a, lit...
# 4        [petter, mattei, s, love, in, the, time, of, m...
#                                ...
# 49995    [i, thought, this, movie, did, a, down, right,...
# 49996    [bad, plot, bad, dialogue, bad, acting, idioti...
# 49997    [i, am, a, catholic, taught, in, parochial, el...
# 49998    [i, m, going, to, have, to, disagree, with, th...
# 49999    [no, one, expects, the, star, trek, movies, to...
# Name: Review, Length: 50000, dtype: object

# %% [markdown]
# # Lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
# Out:
# True

# %%
lemmatizer = WordNetLemmatizer()

def lemmatize_tokens(tokens):
    return [lemmatizer.lemmatize(t, pos='v') for t in tokens]

df['Review'] = df['Review'].apply(lemmatize_tokens)

# %%
df
# Out:
#                                                   Review Sentiment
# 0      [one, of, the, other, reviewers, have, mention...  positive
# 1      [a, wonderful, little, production, the, film, ...  positive
# 2      [i, think, this, be, a, wonderful, way, to, sp...  positive
# 3      [basically, there, s, a, family, where, a, lit...  negative
# 4      [petter, mattei, s, love, in, the, time, of, m...  positive
# ...                                                  ...       ...
# 49995  [i, think, this, movie, do, a, down, right, go...  positive
# 49996  [bad, plot, bad, dialogue, bad, act, idiotic, ...  negative
# 49997  [i, be, a, catholic, teach, in, parochial, ele...  negative
# 49998  [i, m, go, to, have, to, disagree, with, the, ...  negative
# 49999  [no, one, expect, the, star, trek, movies, to,...  negative
#
# [50000 rows x 2 columns]

# %%
df['Review'] = df['Review'].apply(lemmatize_tokens)

# %%
df
# Out:
#                                                   Review Sentiment
# 0      [one, of, the, other, reviewers, have, mention...  positive
# 1      [a, wonderful, little, production, the, film, ...  positive
# 2      [i, think, this, be, a, wonderful, way, to, sp...  positive
# 3      [basically, there, s, a, family, where, a, lit...  negative
# 4      [petter, mattei, s, love, in, the, time, of, m...  positive
# ...                                                  ...       ...
# 49995  [i, think, this, movie, do, a, down, right, go...  positive
# 49996  [bad, plot, bad, dialogue, bad, act, idiotic, ...  negative
# 49997  [i, be, a, catholic, teach, in, parochial, ele...  negative
# 49998  [i, m, go, to, have, to, disagree, with, the, ...  negative
# 49999  [no, one, expect, the, star, trek, movies, to,...  negative
#
# [50000 rows x 2 columns]

# %%
df['Cleaned_Text'] = df['Review'].apply(lambda x: " ".join(x))

# %%
df
# Out:
#                                                   Review Sentiment  \
# 0      [one, of, the, other, reviewers, have, mention...  positive
# 1      [a, wonderful, little, production, the, film, ...  positive
# 2      [i, think, this, be, a, wonderful, way, to, sp...  positive
# 3      [basically, there, s, a, family, where, a, lit...  negative
# 4      [petter, mattei, s, love, in, the, time, of, m...  positive
# ...                                                  ...       ...
# 49995  [i, think, this, movie, do, a, down, right, go...  positive
# 49996  [bad, plot, bad, dialogue, bad, act, idiotic, ...  negative
# 49997  [i, be, a, catholic, teach, in, parochial, ele...  negative
# 49998  [i, m, go, to, have, to, disagree, with, the, ...  negative
# 49999  [no, one, expect, the, star, trek, movies, to,...  negative
#
#                                             Cleaned_Text
# 0      one of the other reviewers have mention that a...
# 1      a wonderful little production the film techniq...
# 2      i think this be a wonderful way to spend time ...
# 3      basically there s a family where a little boy ...
# 4      petter mattei s love in the time of money be a...
# ...                                                  ...
# 49995  i think this movie do a down right good job it...
# 49996  bad plot bad dialogue bad act idiotic direct t...
# 49997  i be a catholic teach in parochial elementary ...
# 49998  i m go to have to disagree with the previous c...
# 49999  no one expect the star trek movies to be high ...
#
# [50000 rows x 3 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer(max_features=5000)

# %%
X = vectorizer.fit_transform(df['Review'])
y= df['Sentiment']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 X = vectorizer.fit_transform(df['Review'])
#       2 y= df['Sentiment']
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\feature_extraction\text.py:2126, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2119 self._check_params()
#    2120 self._tfidf = TfidfTransformer(
#    2121     norm=self.norm,
#    2122     use_idf=self.use_idf,
#    2123     smooth_idf=self.smooth_idf,
#    2124     sublinear_tf=self.sublinear_tf,
#    2125 )
# -> 2126 X = super().fit_transform(raw_documents)
#    2127 self._tfidf.fit(X)
#    2128 # X is already a transformed view of raw_documents so
#    2129 # we set copy to False
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\feature_extraction\text.py:1383, in CountVectorizer.fit_transform(self, raw_documents, y)
#    1375             warnings.warn(
#    1376                 "Upper case characters found in"
#    1377                 " vocabulary while 'lowercase'"
#    1378                 " is True. These entries will not"
#    1379                 " be matched with any documents"
#    1380             )
#    1381             break
# -> 1383 vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#    1385 if self.binary:
#    1386     X.data.fill(1)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\feature_extraction\text.py:1270, in CountVectorizer._count_vocab(self, raw_documents, fixed_vocab)
#    1268 for doc in raw_documents:
#    1269     feature_counter = {}
# -> 1270     for feature in analyze(doc):
#    1271         try:
#    1272             feature_idx = vocabulary[feature]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\feature_extraction\text.py:110, in _analyze(doc, analyzer, tokenizer, ngrams, preprocessor, decoder, stop_words)
#     108 else:
#     109     if preprocessor is not None:
# --> 110         doc = preprocessor(doc)
#     111     if tokenizer is not None:
#     112         doc = tokenizer(doc)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\feature_extraction\text.py:68, in _preprocess(doc, accent_function, lower)
#      49 """Chain together an optional series of text preprocessing steps to
#      50 apply to a document.
#      51
#    (...)
#      65     preprocessed string
#      66 """
#      67 if lower:
# ---> 68     doc = doc.lower()
#      69 if accent_function is not None:
#      70     doc = accent_function(doc)
#
# AttributeError: 'list' object has no attribute 'lower'
